# %% [markdown]
# ## Porcentaje de eficiencia de las tecnologías en RRHH ##

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Datos
data = {
    'Tecnología': [
        'Machine\nLearning', 'Procesamiento\nLenguaje\nNatural', 'Big Data', 'Chatbots',
        'Análisis\nPredictivo', 'Automatización\nRobótica de\nProcesos', 'Reconocimiento\nFacial'
    ],
    'Uso en RRHH': [
        'Predicción\nrotación', 'Análisis\nencuestas', 'Optimización\nselección', 'Asistencia\nautomatizada',
        'Identificación\ntendencias\ncontratación', 'Automatización\ntareas\nadministrativas', 'Control de\nacceso y\nseguridad'
    ],
    'Eficiencia (%)': [76, 80, 88, 75, 82, 90, 78],
}

# Crear DataFrame
df = pd.DataFrame(data)

# Configurar gráfico
fig, ax = plt.subplots(figsize=(15, 6))
bars = ax.bar(df['Tecnología'], df['Eficiencia (%)'], color='#4682B4', edgecolor='white')  # Azul acero

# Ajustar el eje Y con tramos de 10 en 10
ax.set_yticks(np.arange(0, 101, 10))

# Agregar etiquetas con el uso en RRHH
for bar, uso, eficiencia in zip(bars, df['Uso en RRHH'], df['Eficiencia (%)']):
    ax.text(
        bar.get_x() + bar.get_width()/2, bar.get_height() - 5,
        f"{uso}\n{eficiencia}%", ha='center', va='top', fontsize=10, color='white', fontweight='bold'
    )

# Configuración de etiquetas y título
ax.set_xlabel('Tecnologías', fontweight='bold')
ax.set_ylabel('Eficiencia (%)', fontweight='bold')
ax.set_title('Porcentaje de eficiencia de las tecnologías en RRHH', fontweight='bold')

# Eliminar la cuadrícula
ax.grid(False)

# Mostrar gráfico
plt.show()

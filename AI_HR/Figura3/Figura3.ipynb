# %% [markdown]
# ## Diagrama de Modelos de Aprendizaje Automático o Machine Learning ##

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Crear un grafo dirigido
G = nx.DiGraph()

# Nodo central
G.add_node("Fundamentos\nde la IA")

# Ramas principales
ramas = ["Aprendizaje\nSupervisado", "Aprendizaje\nNo\nSupervisado", "Aprendizaje\npor\nRefuerzo"]
ejemplos = {
    "Aprendizaje\nSupervisado": ["Clasificación\nde currículums", "Predecir\ndesempeño\nfuturo"],
    "Aprendizaje\nNo\nSupervisado": ["Segmentación\nde empleados\nsegún perfiles", "Detectar\nanomalías"],
    "Aprendizaje\npor\nRefuerzo": ["Simulaciones\nde dinámicas\nlaborales", "Optimizar\nprocesos\nde selección"]
}

for rama in ramas:
    G.add_node(rama)
    G.add_edge("Fundamentos\nde la IA", rama)
    for ejemplo in ejemplos[rama]:
        G.add_node(ejemplo)
        G.add_edge(rama, ejemplo)

# Definir posiciones manualmente para una mejor estructura
pos = {
    "Fundamentos\nde la IA": (0, 3),
    "Aprendizaje\nSupervisado": (-1, 2),
    "Aprendizaje\nNo\nSupervisado": (0, 2),
    "Aprendizaje\npor\nRefuerzo": (1, 2),
    "Clasificación\nde currículums": (-1.2, 1),
    "Predecir\ndesempeño\nfuturo": (-0.8, 1),
    "Segmentación\nde empleados\nsegún perfiles": (-0.2, 1),
    "Detectar\nanomalías": (0.2, 1),
    "Simulaciones\nde dinámicas\nlaborales": (0.8, 1),
    "Optimizar\nprocesos\nde selección": (1.2, 1)
}

# Dibujar el grafo con texto en blanco
plt.figure(figsize=(12, 8))
nx.draw(G, pos, with_labels=True, node_size=9000, node_color="#4682B4", edge_color="gray",
        font_size=12, font_weight="normal", font_color="white", arrows=True, linewidths=1, 
        edgecolors="white", node_shape="s")  # "s" para nodos rectangulares

plt.show()
